# %% [markdown]
# # Missing value imputation by class

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
path = "income.csv"
path2 = "housetrain.csv" 
dfi = pd.read_csv(path)
dfh = pd.read_csv(path2)

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
dfh.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
dfi.shape
# Out:
# (32526, 19)

# %%
dfi.isnull().sum()
# Out:
# id            0
# State_Code    0
# State_Name    0
# State_ab      0
# County        0
# City          0
# Place         0
# Type          0
# Primary       0
# Zip_Code      0
# Area_Code     0
# ALand         0
# AWater        0
# Lat           0
# Lon           0
# Mean          0
# Median        0
# Stdev         0
# sum_w         0
# dtype: int64

# %%
dfhp = dfh.isnull().sum()/dfh.shape[0]*100
dfhp
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType        0.547945
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# ...

# %%
dfh_20 = dfhp[dfhp>20].keys()

# %%
dfh_20
# Out:
# Index(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
df_drop = dfh.drop(columns=dfh_20)

# %%
df_drop.shape
# Out:
# (1460, 76)

# %%
df_num = df_drop.select_dtypes(include=['int64','float64'])

# %%
df_num.shape
# Out:
# (1460, 38)

# %%
df_num.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
df_num[df_num.isnull().any(axis=1)].head()
# Out:
#     Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 7    8          60          NaN    10382            7            6       1973
# 12  13          20          NaN    12968            5            6       1962
# 14  15          20          NaN    10920            6            5       1960
# 16  17          20          NaN    11241            6            7       1970
# 24  25          20          NaN     8246            5            8       1968
#
#     YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 7           1973       240.0         859          32        216         1107
# 12          1962         0.0         737           0        175          912
# 14          1960       212.0         733           0        520         1253
# 16          1970       180.0         578           0        426         1004
# 24          2001         0.0         188         668        204         1060
#
# ...

# %%
df_col = [i for i in df_num.columns if df_num[i].isnull().sum()>0]

# %%
df_col
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
df_num[df_col][df_num[df_col].isnull().any(axis=1)].head()
# Out:
#     LotFrontage  MasVnrArea  GarageYrBlt
# 7           NaN       240.0       1973.0
# 12          NaN         0.0       1962.0
# 14          NaN       212.0       1960.0
# 16          NaN       180.0       1970.0
# 24          NaN         0.0       1968.0

# %%
dfh['LotConfig'].unique()
# Out:
# array(['Inside', 'FR2', 'Corner', 'CulDSac', 'FR3'], dtype=object)

# %%
dfh[dfh.loc[:,'LotConfig']=='Inside']['LotFrontage'].replace(np.nan,dfh[dfh.loc[:,'LotConfig']=='Inside']['LotFrontage'].mean())
# Out:
# 0        65.000000
# 2        68.000000
# 5        85.000000
# 6        75.000000
# 8        51.000000
# 10       70.000000
# 11       85.000000
# 12       67.715686
# 13       91.000000
# 17       72.000000
# 18       66.000000
# 19       70.000000
# 21       57.000000
# 22       75.000000
# 23       44.000000
# 24       67.715686
# 27       98.000000
# 29       60.000000
# 30       50.000000
# 33       70.000000
# 34       60.000000
# 35      108.000000
# 37       74.000000
# 38       68.000000
# 39       65.000000
# 40       84.000000
# 41      115.000000
# 44       70.000000
# 45       61.000000
# 47       84.000000
# 48       33.000000
# 49       66.000000
# 51       52.000000
# 53       68.000000
# 54       60.000000
# 55      100.000000
# 56       24.000000
# 59       60.000000
# 60       63.000000
# 61       60.000000
# 62       44.000000
# 63       50.000000
# 64       67.715686
# 65       76.000000
# 66       67.715686
# 67       72.000000
# 70       95.000000
# ...

# %%
df_copy=dfh.copy()
for var_class in dfh['LotConfig'].unique():
    df_copy.update(dfh[dfh.loc[:,'LotConfig']==var_class]['LotFrontage'].replace(np.nan,dfh[dfh.loc[:,'LotConfig']==var_class]['LotFrontage'].mean()))

# %%
df_copy.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage         0
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
df_copy=dfh.copy()
df_misss = ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
cat_vars = ['LotConfig','Exterior2nd','KitchenQual']
for cat_var,df_miss in zip(cat_vars,df_misss):
    for var_class in dfh[cat_var].unique():
        df_copy.update(dfh[dfh.loc[:,cat_var]==var_class][df_miss].replace(np.nan,dfh[dfh.loc[:,cat_var]==var_class][df_miss].mean()))

# %%
df_copy[df_misss].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
df_copy[df_copy[["MasVnrType"]].isnull().any(axis=1)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 234    235          60       RL    67.715686     7851   Pave   NaN      Reg
# 529    530          20       RL    59.911111    32668   Pave   NaN      IR1
# 650    651          60       FV    65.000000     8125   Pave   NaN      Reg
# 936    937          20       RL    67.000000    10083   Pave   NaN      Reg
# 973    974          20       FV    95.000000    11639   Pave   NaN      Reg
# 977    978         120       FV    35.000000     4274   Pave  Pave      IR1
# 1243  1244          20       RL   107.000000    13891   Pave   NaN      Reg
# 1278  1279          60       RL    75.000000     9473   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 234          Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 529          Lvl    AllPub   CulDSac       Gtl      Crawfor       Norm
# ...

# %% [markdown]
# # data distribution

# %%
plt.figure(figsize=(10,10))
sns.set()
for i,var in enumerate(df_misss):
    plt.subplot(2,2,i+1)
    sns.distplot(dfh[var],bins=10, kde_kws={'color':'red'}, label="original")
    sns.distplot(df_copy[var],bins=10, kde_kws={'color':'green'},label="copy")
#     sns.distplot(df4_median[var],bins=10, kde_kws={'color':'blue'},label="median")
    plt.legend()
# Out:
# C:\Users\Sanjay\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sanjay\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # Median

# %%
df_copy_median=dfh.copy()
df_misss = ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
cat_vars = ['LotConfig','Exterior2nd','KitchenQual']
for cat_var,df_miss in zip(cat_vars,df_misss):
    for var_class in dfh[cat_var].unique():
        df_copy_median.update(dfh[dfh.loc[:,cat_var]==var_class][df_miss].replace(np.nan,dfh[dfh.loc[:,cat_var]==var_class][df_miss].median()))

# %%
df_copy_median[df_misss].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.set()
for i,var in enumerate(df_misss):
    plt.subplot(2,2,i+1)
    sns.distplot(dfh[var],bins=10, kde_kws={'color':'red'}, label="original")
    sns.distplot(df_copy_median[var],bins=10, kde_kws={'color':'green'},label="median")
    sns.distplot(df_copy[var],bins=10, kde_kws={'color':'blue'},label="mean")
    plt.legend()
# Out:
# C:\Users\Sanjay\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sanjay\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for i,var in enumerate(df_misss):
    plt.figure(figsize=(10,10))
    plt.subplot(3,1,1)
    sns.boxplot(dfh[var])
    plt.subplot(3,1,2)
    sns.boxplot(df_copy[var])
    plt.subplot(3,1,3)
    sns.boxplot(df_copy_median[var])
    plt.legend()
# Out:
# C:\Users\Sanjay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Sanjay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Sanjay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...
